# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import sqlalchemy

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = 'https://www.justia.com/lawyers/california/san-francisco'

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website)

# %% [markdown]
# #### Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')
# soup

# %% [markdown]
# ### Results

# %%
results = soup.find_all('div', {'data-vars-action':'OrganicListing'})

# %%
len(results)
# Out:
# 40

# %% [markdown]
# ### Target necessary data

# %%
# Name
# Short Bio
# Specialization
# University
# Address
# Phone
# Email Link

# %% [markdown]
# #### Name

# %%
results[0].find('strong', {'class':'lawyer-name'}).get_text().strip()
# Out:
# 'Doug Bend'

# %% [markdown]
# #### Short Bio

# %%
results[0].find('div', {'class':'lawyer-expl'}).get_text().strip()
# Out:
# 'San Francisco, CA Attorney'

# %% [markdown]
# #### Specialization

# %%
results[0].find('span', {'class':'-practices'}).get_text()
# Out:
# 'Business, Entertainment & Sports, Real Estate and Trademarks'

# %% [markdown]
# #### University

# %%
results[0].find('span', {'class':'-law-schools'}).get_text()
# Out:
# 'Georgetown University Law Center'

# %% [markdown]
# #### Address

# %%
results[0].find('span', {'class':'-address'}).get_text().strip().replace('\t', '').replace('\n', '')
# Out:
# '2181 Greenwich StreetSan Francisco,CA 94123'

# %% [markdown]
# #### Phone

# %%
results[0].find('strong', {'class':'-phone'}).get_text().strip()
# Out:
# '(415) 633-6841'

# %% [markdown]
# #### Email Link

# %%
results[0].find('a', {'class':'-email'}).get('href')
# Out:
# 'https://lawyers.justia.com/lawyer/doug-bend-1662623/contact'

# %% [markdown]
# ### Put everything together inside a For-Loop

# %%
name = []
short_bio = []
specialization = []
university = []
address = []
phone = []
email_link = []

for result in results:
    
    # name
    try:
        name.append(result.find('strong', {'class':'lawyer-name'}).get_text().strip())
    except:
        name.append('')
    
    # short bio
    try:
        short_bio.append(result.find('div', {'class':'lawyer-expl'}).get_text().strip())
    except:
        short_bio.append('')
    
    # specialization
    try:
        specialization.append(result.find('span', {'class':'-practices'}).get_text())
    except:
        specialization.append('')
    
    # university
    try:
        university.append(result.find('span', {'class':'-law-schools'}).get_text())
    except:
        university.append('')
    
    # address
    try:
        address.append(result.find('span', {'class':'-address'}).get_text().strip().replace('\t', '').replace('\n', ''))
    except:
        address.append('')
    
    # phone
    try:
        phone.append(result.find('strong', {'class':'-phone'}).get_text().strip())
    except:
        phone.append('')
    
    # email
    try:
        email_link.append(result.find('a', {'class':'-email'}).get('href'))
    except:
        email_link.append('')

# %% [markdown]
# ### Create Pandas Dataframe

# %%
df_lawyers = pd.DataFrame({'lawyer_name': name, 'short_bio': short_bio, 'specialization':specialization,
                          'university':university, 'address':address, 'phone':phone, 'email':email_link})

# %%
df_lawyers
# Out:
#                  lawyer_name  \
# 0                  Doug Bend
# 1        Michael Paul Ehline
# 2      Ali Shahrestani, Esq.
# 3             Christina Weed
# 4             Joseph Tobener
# 5     Arnold Isaac Berschler
# 6            Aaron R. Bortel
# 7             Garrett Sutton
# 8       George W. Wolff Esq.
# 12  https://lawyers.justia.com/lawyer/michael-a-ke...
# 13  https://lawyers.justia.com/lawyer/lindsay-gunn...
# 14  https://lawyers.justia.com/lawyer/sweta-khande...
# 15  https://lawyers.justia.com/lawyer/randall-h-sc...
# 16
# 17  https://lawyers.justia.com/lawyer/debra-schoen...
# 18  https://lawyers.justia.com/lawyer/nina-g-shapi...
# 19  https://lawyers.justia.com/lawyer/sam-amin-150...
# 20  https://lawyers.justia.com/lawyer/steve-charle...
# 21  https://lawyers.justia.com/lawyer/colby-lavell...
# 22  https://lawyers.justia.com/lawyer/pezhman-pakn...
# 23  https://lawyers.justia.com/lawyer/mr-matthew-j...
# 24  https://lawyers.justia.com/lawyer/gregory-j-br...
# 25  https://lawyers.justia.com/lawyer/josh-s-brown...
# 26  https://lawyers.justia.com/lawyer/alexander-ku...
# 27  https://lawyers.justia.com/lawyer/matt-a-sulli...
# 28  https://lawyers.justia.com/lawyer/paul-deangel...
# 29  https://lawyers.justia.com/lawyer/marin-cionca...
# 30  https://lawyers.justia.com/lawyer/eric-l-tosca...
# 31  https://lawyers.justia.com/lawyer/richard-alex...
# 32
# 33  https://lawyers.justia.com/lawyer/christopher-...
# 34  https://lawyers.justia.com/lawyer/matthew-s-ke...
# 35  https://lawyers.justia.com/lawyer/julia-wobbe-...
# 36  https://lawyers.justia.com/lawyer/john-michael...
# 37  https://lawyers.justia.com/lawyer/gene-takagi-...
# 38  https://lawyers.justia.com/lawyer/aaron-a-pell...
# 39  https://lawyers.justia.com/lawyer/robert-w-ott...

# %% [markdown]
# ### Output in Excel

# %%
df_lawyers.to_excel('lawyers_single.xlsx', index=False)

# %% [markdown]
# ### Part 2 - Pagination - Scrape 20 Pages

# %%
name = []
short_bio = []
specialization = []
university = []
address = []
phone = []
email_link = []


for i in range(1,21):
    
    website = 'https://www.justia.com/lawyers/california/san-francisco?page=' + str(i) 
    
    response = requests.get(website)
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    results = soup.find_all('div', {'data-vars-action':'OrganicListing'})
    
    for result in results:
    
        # name
        try:
            name.append(result.find('strong', {'class':'lawyer-name'}).get_text().strip())
        except:
            name.append('')

        # short bio
        try:
            short_bio.append(result.find('div', {'class':'lawyer-expl'}).get_text().strip())
        except:
            short_bio.append('')

        # specialization
        try:
            specialization.append(result.find('span', {'class':'-practices'}).get_text())
        except:
            specialization.append('')

        # university
        try:
            university.append(result.find('span', {'class':'-law-schools'}).get_text())
        except:
            university.append('')

        # address
        try:
            address.append(result.find('span', {'class':'-address'}).get_text().strip().replace('\t', '').replace('\n', ''))
        except:
            address.append('')

        # phone
        try:
            phone.append(result.find('strong', {'class':'-phone'}).get_text().strip())
        except:
            phone.append('')

        # email
        try:
            email_link.append(result.find('a', {'class':'-email'}).get('href'))
        except:
            email_link.append('')
    
    
df_lawyers_multiple = pd.DataFrame({'lawyer_name': name, 'short_bio': short_bio, 'specialization':specialization,
                          'university':university, 'address':address, 'phone':phone, 'email':email_link})    

df_lawyers_multiple
# Out:
#                 lawyer_name  \
# 0                 Doug Bend
# 1                  Sam Amin
# 2          Debra Schoenberg
# 3     Ali Shahrestani, Esq.
# 4         Richard Alexander
# ..                      ...
# 795      Christian Pedersen
# 796   Paul Gerard Minoletti
# 797  Stuart Milton Flashman
# 798   Thomas John Greenberg
# 799   Kendall David Coffman
#
#                                              short_bio  \
# 0                           San Francisco, CA Attorney
# 1                           San Francisco, CA Attorney
# 2    San Francisco, CA Attorney with 34 years of ex...
# 3    San Francisco, CA Lawyer with 14 years of expe...
# 4    San Francisco, CA Attorney with 50 years of ex...
# ..                                                 ...
# 795                              Richmond, CA Attorney
# 796  San Mateo, CA Attorney with 36 years of experi...
# 797     Oakland, CA Lawyer with 31 years of experience
# 798                              10.0  (1 Peer Review)
# 799   San Mateo, CA Lawyer with 24 years of experience
#
#                                         specialization  \
# 0    Business, Entertainment & Sports, Real Estate ...
# 1                                     Criminal and DUI
# 2                                   Divorce and Family
# 3            Business, Criminal, Divorce and Education
# 4    Asbestos, Consumer, Personal Injury and Produc...
# ..                                                 ...
# 795                                    Personal Injury
# 796  Arbitration & Mediation, Business, Constructio...
# 797                                      Environmental
# 798  Civil Rights, Criminal, DUI and Domestic Violence
# 799                                         Bankruptcy
#
#                                             university  \
# 0                     Georgetown University Law Center
# 1                           John F. Kennedy University
# 2            University of New Hampshire School of Law
# 3    University of California Hastings College of t...
# 4                 The University of Chicago Law School
# ..                                                 ...
# 795                           Arizona State University
# 796                     Golden Gate Univ School of Law
# 797                       New Coll of CA School of Law
# 798
# 799                   University of California - Davis
#
#                                                address           phone  \
# 0          2181 Greenwich StreetSan Francisco,CA 94123  (415) 633-6841
# 1    75 Broadway StreetSuite 202San Francisco,CA 94111  (415) 300-2037
# 2              575 Market StreetSan Francisco,CA 94105  (415) 834-1120
# 3    One Embarcadero CenterSuite 500San Francisco,C...  (800) 510-3916
# 4     1 Sansome StreetSuite 3500San Francisco,CA 94104  (415) 921-1776
# ..                                                 ...             ...
# 795            3150 Hilltop Mall RoadRichmond,CA 94806  (707) 426-5300
# 796  Waters Technology Park1 Waters Park Drive, Sui...  (650) 638-9601
# 797                 5626 Ocean View DrOakland,CA 94618  (510) 652-5373
# 798           605 Middlefield Rd.Redwood City,CA 94063  (650) 242-0021
# 799  1670 South Amphlett BoulevardSuite 214San Mate...  (650) 378-2421
#
#                                                  email
# 0    https://lawyers.justia.com/lawyer/doug-bend-16...
# 1    https://lawyers.justia.com/lawyer/sam-amin-150...
# 2    https://lawyers.justia.com/lawyer/debra-schoen...
# 3    https://lawyers.justia.com/lawyer/ali-shahrest...
# 4    https://lawyers.justia.com/lawyer/richard-alex...
# ..                                                 ...
# 795  https://lawyers.justia.com/lawyer/christian-pe...
# 796  https://lawyers.justia.com/lawyer/paul-gerard-...
# 797  https://lawyers.justia.com/lawyer/stuart-milto...
# 798  https://lawyers.justia.com/lawyer/thomas-john-...
# 799  https://lawyers.justia.com/lawyer/kendall-davi...
#
# [800 rows x 7 columns]

# %% [markdown]
# #### Excel

# %%
df_lawyers_multiple.to_excel('lawyers_multiple.xlsx', index=False)

# %% [markdown]
# #### Postgres

# %%
# create sqlalchemy engine
engine = sqlalchemy.create_engine('postgres://postgres:12345@localhost:5432')
df_lawyers_multiple.to_sql('lawyers', engine, index = False)
